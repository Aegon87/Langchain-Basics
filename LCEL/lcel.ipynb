# %%
import os
from dotenv import load_dotenv
load_dotenv()

GROQ_API_KEY = os.getenv("GROQ_API_KEY")

# %%
# Creating a prompt template
from langchain_core.prompts import ChatPromptTemplate

generic_template = "Translare the following into {language}"
prompt = ChatPromptTemplate.from_messages([
    ("system", generic_template),
    ("human", "{text}")
])

# %%
#Checking the prompt
result = prompt.invoke({"language": "French", "text": "Hello, how are you?"})
result.to_messages()
# Out:
# [SystemMessage(content='Translare the following into French', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='Hello, how are you?', additional_kwargs={}, response_metadata={})]

# %%
# llm model
from langchain_groq import ChatGroq

model = ChatGroq(model="llama-3.3-70b-versatile", api_key=GROQ_API_KEY)

# %%
# Output parser
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

# %%
# Creating a chain
chain =  prompt | model | parser
chain.invoke({"language": "French", "text": "I am fine thank you!"})
# Out:
# 'Je vais bien, merci !'
